# %% [markdown]
# ### 5.1 y 5.2 plots

# %%
import pickle
import numpy as np
import os
import sys

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

from helper_functions import plot_metrics, plot_firing_rates
# Out:
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# 2025-06-03 17:28:40.472599: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748964520.492835   63261 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748964520.498686   63261 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748964520.514607   63261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748964520.514629   63261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748964520.514630   63261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748964520.514632   63261 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-03 17:28:40.520320: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## FFNN Full
# #### Juntamos todos los valores en un único array

# %%
# --- Cargamos los datos ---

# Stage 1
pkl_path = "outputs/ffnn_cartpole_full.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_1, \
    actor_loss_history_1, \
    critic_loss_history_1, \
    actor_firing_rates_1, \
    critic_firing_rates_1, \
    measurements_juices_1 = pickle.load(f)

# --- Juntamos los arrays ---
total_rewards_history = np.concatenate([
    total_rewards_history_1
])

actor_loss_history = np.concatenate([
    actor_loss_history_1
])

critic_loss_history = np.concatenate([
    critic_loss_history_1
])

# --- Representamos los resultados ---
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=20,
    window_2=100
)

# plot_firing_rates(actor_firing_rates_1, critic_firing_rates_1)
# Out:
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# 2025-06-02 22:21:07.905540: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748895669.348597  169616 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748895669.685142  169616 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1748895673.470143  169616 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748895673.470166  169616 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748895673.470167  169616 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1748895673.470169  169616 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-02 22:21:13.885748: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## FFNN Partial

# %%
# --- Cargamos los datos ---

# Stage 1
pkl_path = "outputs/ffnn_cartpole_partial.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_1, \
    actor_loss_history_1, \
    critic_loss_history_1, \
    actor_firing_rates_1, \
    critic_firing_rates_1, \
    measurements_juices_1 = pickle.load(f)

# Stage 2
pkl_path = "outputs/ffnn_cartpole_partial_2.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_2, \
    actor_loss_history_2, \
    critic_loss_history_2, \
    actor_firing_rates_2, \
    critic_firing_rates_2, \
    measurements_juices_2 = pickle.load(f)

# Stage 3
pkl_path = "outputs/ffnn_cartpole_partial_3.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_3, \
    actor_loss_history_3, \
    critic_loss_history_3, \
    actor_firing_rates_3, \
    critic_firing_rates_3, \
    measurements_juices_3 = pickle.load(f)

# Stage 4
pkl_path = "outputs/ffnn_cartpole_partial_4.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_4, \
    actor_loss_history_4, \
    critic_loss_history_4, \
    actor_firing_rates_4, \
    critic_firing_rates_4, \
    measurements_juices_4 = pickle.load(f)

# --- Juntamos los arrays ---
total_rewards_history = np.concatenate([
    total_rewards_history_1,
    total_rewards_history_2,
    total_rewards_history_3,
    total_rewards_history_4
])

actor_loss_history = np.concatenate([
    actor_loss_history_1,
    actor_loss_history_2,
    actor_loss_history_3,
    actor_loss_history_4
])

critic_loss_history = np.concatenate([
    critic_loss_history_1,
    critic_loss_history_2,
    critic_loss_history_3,
    critic_loss_history_4
])

# --- Representamos los resultados ---
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=50,
    window_2=500
)

# plot_firing_rates(actor_firing_rates_1, critic_firing_rates_1)

# %% [markdown]
# ## RNN Full

# %%
# --- Cargamos los datos ---

# Stage 1
pkl_path = "outputs/rnn_cartpole_full.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_1, \
    actor_loss_history_1, \
    critic_loss_history_1, \
    actor_firing_rates_1, \
    critic_firing_rates_1, \
    measurements_juices_1 = pickle.load(f)

# Stage 2
pkl_path = "outputs/rnn_cartpole_full_2.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_2, \
    actor_loss_history_2, \
    critic_loss_history_2, \
    actor_firing_rates_2, \
    critic_firing_rates_2, \
    measurements_juices_2 = pickle.load(f)

# --- Juntamos los arrays ---
total_rewards_history = np.concatenate([
    total_rewards_history_1,
    total_rewards_history_2
])

actor_loss_history = np.concatenate([
    actor_loss_history_1,
    actor_loss_history_2
])

critic_loss_history = np.concatenate([
    critic_loss_history_1,
    critic_loss_history_2
])

# --- Representamos los resultados ---
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=20,
    window_2=100
)

plot_firing_rates(actor_firing_rates_2, critic_firing_rates_2)
# Out:
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:537: RuntimeWarning: Mean of empty slice
#   last_episode = np.nanmean(tensor[:, :, -1], axis=0)

# %% [markdown]
# ## RNN Partial

# %%
# --- Cargamos los datos ---

# Stage 1
pkl_path = "outputs/rnn_cartpole_partial.pkl"

with open(pkl_path, "rb") as f:
    total_rewards_history_1, \
    actor_loss_history_1, \
    critic_loss_history_1, \
    actor_firing_rates_1, \
    critic_firing_rates_1, \
    measurements_juices_1 = pickle.load(f)

# Stage 2
pkl_path = "outputs/rnn_cartpole_partial_2.pkl"

with open(pkl_path, "rb") as f:
   total_rewards_history_2, \
   actor_loss_history_2, \
   critic_loss_history_2, \
   actor_firing_rates_2, \
   critic_firing_rates_2, \
   measurements_juices_2 = pickle.load(f)

# --- Juntamos los arrays ---
total_rewards_history = np.concatenate([
    total_rewards_history_1,
    total_rewards_history_2
])

actor_loss_history = np.concatenate([
    actor_loss_history_1,
    actor_loss_history_2
])

critic_loss_history = np.concatenate([
    critic_loss_history_1,
    critic_loss_history_2
])

# --- Representamos los resultados ---
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=100,
    window_2=500
)

plot_firing_rates(actor_firing_rates_2, critic_firing_rates_2)
# Out:
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:536: RuntimeWarning: Mean of empty slice
#   first_episode = np.nanmean(tensor[:, :, 0], axis=0)
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:537: RuntimeWarning: Mean of empty slice
#   last_episode = np.nanmean(tensor[:, :, -1], axis=0)
