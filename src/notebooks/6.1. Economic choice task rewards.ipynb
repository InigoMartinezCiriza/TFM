# %% [markdown]
# ### RNN: economic choice

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_2 import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 0
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_decision": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 500,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_decision=config["reward_go_decision"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# 2025-04-22 12:00:03.069306: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745316005.033544  267572 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745316005.561171  267572 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745316010.483500  267572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745316010.483537  267572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745316010.483545  267572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745316010.483552  267572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-22 12:00:10.965977: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_decision: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 500
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 6, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('B', 'A'), 'offer_BA': (6, 1), 'nL': 6, 'nR': 1, 'rL': 600, 'rR': 220.00000000000003, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_dec_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# 2025-04-22 12:01:08.297206: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Agent Initialized.
# Starting training for 500 episodes...
# Episode 10	Total Reward: -1.00	Actor Loss: -1.0147	Critic Loss: 0.7843
# Episode 20	Total Reward: -1.00	Actor Loss: -0.5575	Critic Loss: 0.2812
# Episode 30	Total Reward: -1.00	Actor Loss: 0.0621	Critic Loss: 0.0036
# Episode 40	Total Reward: -1.00	Actor Loss: -0.1852	Critic Loss: 0.0305
# Episode 50	Total Reward: -1.00	Actor Loss: -0.1396	Critic Loss: 0.0173
# Episode 60	Total Reward: -0.90	Actor Loss: 0.5127	Critic Loss: 0.3511
# Episode 70	Total Reward: -0.70	Actor Loss: 0.8583	Critic Loss: 0.9749
# Episode 80	Total Reward: -1.00	Actor Loss: -0.4364	Critic Loss: 0.1232
# Episode 90	Total Reward: -1.00	Actor Loss: -0.2370	Critic Loss: 0.0489
# Episode 100	Total Reward: -1.00	Actor Loss: -0.1524	Critic Loss: 0.0146
# Episode 110	Total Reward: -1.00	Actor Loss: -0.2160	Critic Loss: 0.0397
# Episode 120	Total Reward: -1.00	Actor Loss: -0.2892	Critic Loss: 0.0691
# Episode 130	Total Reward: -0.90	Actor Loss: 0.1165	Critic Loss: 0.0192
# Episode 140	Total Reward: -1.00	Actor Loss: -0.1889	Critic Loss: 0.0188
# Episode 150	Total Reward: -1.00	Actor Loss: -0.1106	Critic Loss: 0.0088
# Episode 160	Total Reward: -1.00	Actor Loss: 0.0210	Critic Loss: 0.0003
# Episode 170	Total Reward: -0.80	Actor Loss: -0.0240	Critic Loss: 0.0157
# Episode 180	Total Reward: -1.00	Actor Loss: -0.0720	Critic Loss: 0.0021
# Episode 190	Total Reward: 13.50	Actor Loss: 0.1039	Critic Loss: 59.3444
# Episode 200	Total Reward: -1.00	Actor Loss: -0.1323	Critic Loss: 0.0061
# Episode 210	Total Reward: 25.40	Actor Loss: -0.0139	Critic Loss: 87.4061
# Episode 220	Total Reward: -1.00	Actor Loss: -1.1087	Critic Loss: 0.1439
# Episode 230	Total Reward: 22.20	Actor Loss: -0.1001	Critic Loss: 59.9860
# Episode 240	Total Reward: 23.80	Actor Loss: -0.0268	Critic Loss: 19.5473
# Episode 250	Total Reward: 26.30	Actor Loss: -0.0393	Critic Loss: 26.5649
# Episode 260	Total Reward: 26.20	Actor Loss: -0.0502	Critic Loss: 28.6930
# Episode 270	Total Reward: 33.10	Actor Loss: -0.0084	Critic Loss: 48.1851
# Episode 280	Total Reward: 30.30	Actor Loss: -0.0961	Critic Loss: 24.0736
# Episode 290	Total Reward: 30.80	Actor Loss: -0.0544	Critic Loss: 22.9464
# Episode 300	Total Reward: 28.80	Actor Loss: 0.0069	Critic Loss: 49.0709
# Episode 310	Total Reward: 27.90	Actor Loss: -0.1866	Critic Loss: 96.3936
# Episode 320	Total Reward: 25.20	Actor Loss: 0.0021	Critic Loss: 16.9472
# Episode 330	Total Reward: 30.00	Actor Loss: 0.0022	Critic Loss: 27.2407
# Episode 340	Total Reward: 27.70	Actor Loss: -0.0085	Critic Loss: 14.7532
# Episode 350	Total Reward: 25.50	Actor Loss: 0.0050	Critic Loss: 10.5819
# Episode 360	Total Reward: 27.20	Actor Loss: -0.0059	Critic Loss: 13.4935
# Episode 370	Total Reward: 31.60	Actor Loss: 0.0054	Critic Loss: 30.7356
# Episode 380	Total Reward: 33.10	Actor Loss: -0.0232	Critic Loss: 37.4288
# Episode 390	Total Reward: 24.20	Actor Loss: -0.0951	Critic Loss: 120.0592
# Episode 400	Total Reward: 36.30	Actor Loss: -0.0513	Critic Loss: 76.1847
# Episode 410	Total Reward: 16.20	Actor Loss: -0.5129	Critic Loss: 1107.0305
# Episode 420	Total Reward: 23.60	Actor Loss: -0.1348	Critic Loss: 72.1886
# Episode 430	Total Reward: 285.10	Actor Loss: 0.3070	Critic Loss: 57659.9570
# Episode 440	Total Reward: 166.20	Actor Loss: -0.0267	Critic Loss: 3738.1218
# Episode 450	Total Reward: 18.30	Actor Loss: -0.9872	Critic Loss: 4959.1875
# Episode 460	Total Reward: 54.10	Actor Loss: -0.5513	Critic Loss: 690.9175
# Episode 470	Total Reward: 28.70	Actor Loss: -0.4146	Critic Loss: 1578.6925
# Episode 480	Total Reward: 465.20	Actor Loss: 0.4390	Critic Loss: 113505.3516
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 122
#     118 # --- Training ---
#     119 print(f"Starting training for {config['num_episodes']} episodes...")
#     121 total_rewards_history, actor_loss_history, critic_loss_history, \
# --> 122 actor_firing_rates, critic_firing_rates = train_agent(
#     123     env=env,
#     124     agent=agent,
#     125     num_episodes=config["num_episodes"],
#     126     gamma=config["gamma"],
#     127     print_interval=config["print_interval"],
#     128     l2_actor=config["l2_actor"],
#     129     l2_critic=config["l2_critic"],
#     130     record_history=config["record_history"]
#     131 )
#     133 print("\nTraining finished.")
#     135 # --- Plot Training Metrics ---
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/reinforce.py:86, in train_agent(env, agent, num_episodes, gamma, print_interval, record_history, l2_actor, l2_critic)
#      83     actor_hidden_states_ep.append(current_actor_hidden[0].numpy().flatten())
#      85 # Environment steps
# ---> 86 next_state, reward, terminated, truncated, _ = env.step(action)
#      87 done = terminated or truncated
#      89 # Store data for this step
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/env_economic_choice_2.py:247, in EconomicChoiceEnv.step(self, action)
#     245 """Advances the environment by one time step."""
#     246 if not (0 <= action < self.action_space.n):
# --> 247     raise ValueError(f"Invalid action: {action}. Action must be in [0, {self.action_space.n-1}]")
#     249 terminated = False
#     250 truncated = False
#
# ValueError: Invalid action: 3. Action must be in [0, 2]

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_2 import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 0
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_decision": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 450,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_decision=config["reward_go_decision"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' already in sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_decision: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 450
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 6, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('B', 'A'), 'offer_BA': (6, 1), 'nL': 6, 'nR': 1, 'rL': 600, 'rR': 220.00000000000003, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_dec_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# Agent Initialized.
#
# Episode 220	Total Reward: -1.00	Actor Loss: -1.1087	Critic Loss: 0.1439
# Episode 230	Total Reward: 22.20	Actor Loss: -0.1001	Critic Loss: 59.9860
# Episode 240	Total Reward: 23.80	Actor Loss: -0.0268	Critic Loss: 19.5473
# Episode 250	Total Reward: 26.30	Actor Loss: -0.0393	Critic Loss: 26.5649
# Episode 260	Total Reward: 26.20	Actor Loss: -0.0502	Critic Loss: 28.6930
# Episode 270	Total Reward: 33.10	Actor Loss: -0.0084	Critic Loss: 48.1851
# Episode 280	Total Reward: 30.30	Actor Loss: -0.0961	Critic Loss: 24.0736
# Episode 290	Total Reward: 30.80	Actor Loss: -0.0544	Critic Loss: 22.9464
# Episode 300	Total Reward: 28.80	Actor Loss: 0.0069	Critic Loss: 49.0709
# Episode 310	Total Reward: 27.90	Actor Loss: -0.1866	Critic Loss: 96.3936
# Episode 320	Total Reward: 25.20	Actor Loss: 0.0021	Critic Loss: 16.9472
# Episode 330	Total Reward: 30.00	Actor Loss: 0.0022	Critic Loss: 27.2407
# Episode 340	Total Reward: 27.70	Actor Loss: -0.0085	Critic Loss: 14.7532
# Episode 350	Total Reward: 25.50	Actor Loss: 0.0050	Critic Loss: 10.5819
# Episode 360	Total Reward: 27.20	Actor Loss: -0.0059	Critic Loss: 13.4935
# Episode 370	Total Reward: 31.60	Actor Loss: 0.0054	Critic Loss: 30.7356
# Episode 380	Total Reward: 33.10	Actor Loss: -0.0232	Critic Loss: 37.4288
# Episode 390	Total Reward: 24.20	Actor Loss: -0.0951	Critic Loss: 120.0592
# Episode 400	Total Reward: 36.30	Actor Loss: -0.0513	Critic Loss: 76.1847
# Episode 410	Total Reward: 16.20	Actor Loss: -0.5129	Critic Loss: 1107.0305
# Episode 420	Total Reward: 23.60	Actor Loss: -0.1348	Critic Loss: 72.1886
# Episode 430	Total Reward: 285.10	Actor Loss: 0.3070	Critic Loss: 57659.9570
# Episode 440	Total Reward: 166.20	Actor Loss: -0.0267	Critic Loss: 3738.1218
# Episode 450	Total Reward: 18.30	Actor Loss: -0.9872	Critic Loss: 4959.1875
# Episode 460	Total Reward: 54.10	Actor Loss: -0.5513	Critic Loss: 690.9175
# Episode 470	Total Reward: 28.70	Actor Loss: -0.4146	Critic Loss: 1578.6925
# Episode 480	Total Reward: 465.20	Actor Loss: 0.4390	Critic Loss: 113505.3516
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 122
#     118 # --- Training ---
#     119 print(f"Starting training for {config['num_episodes']} episodes...")
#     121 total_rewards_history, actor_loss_history, critic_loss_history, \
# --> 122 actor_firing_rates, critic_firing_rates = train_agent(
#     123     env=env,
#     124     agent=agent,
#     125     num_episodes=config["num_episodes"],
#     126     gamma=config["gamma"],
#     127     print_interval=config["print_interval"],
#     128     l2_actor=config["l2_actor"],
#     129     l2_critic=config["l2_critic"],
#     130     record_history=config["record_history"]
#     131 )
#     133 print("\nTraining finished.")
#     135 # --- Plot Training Metrics ---
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/reinforce.py:86, in train_agent(env, agent, num_episodes, gamma, print_interval, record_history, l2_actor, l2_critic)
#      83     actor_hidden_states_ep.append(current_actor_hidden[0].numpy().flatten())
#      85 # Environment steps
# ---> 86 next_state, reward, terminated, truncated, _ = env.step(action)
#      87 done = terminated or truncated
#      89 # Store data for this step
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/env_economic_choice_2.py:247, in EconomicChoiceEnv.step(self, action)
#     245 """Advances the environment by one time step."""
#     246 if not (0 <= action < self.action_space.n):
# --> 247     raise ValueError(f"Invalid action: {action}. Action must be in [0, {self.action_space.n-1}]")
#     249 terminated = False
#     250 truncated = False
#
# ValueError: Invalid action: 3. Action must be in [0, 2]

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_2 import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 0
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_decision": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 500,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_decision=config["reward_go_decision"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' already in sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_decision: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 500
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 6, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('B', 'A'), 'offer_BA': (6, 1), 'nL': 6, 'nR': 1, 'rL': 600, 'rR': 220.00000000000003, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_dec_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# Agent Initialized.
# Starting training for 500 episodes...
# Episode 10	Total Reward: -1.00	Actor Loss: -1.0147	Critic Loss: 0.7843
# Episode 20	Total Reward: -1.00	Actor Loss: -0.5575	Critic Loss: 0.2812
# Episode 30	Total Reward: -1.00	Actor Loss: 0.0621	Critic Loss: 0.0036
# Episode 40	Total Reward: -1.00	Actor Loss: -0.1852	Critic Loss: 0.0305
# Episode 50	Total Reward: -1.00	Actor Loss: -0.1396	Critic Loss: 0.0173
# Episode 60	Total Reward: -0.90	Actor Loss: 0.5127	Critic Loss: 0.3511
# Episode 70	Total Reward: -0.70	Actor Loss: 0.8583	Critic Loss: 0.9749
# Episode 80	Total Reward: -1.00	Actor Loss: -0.4364	Critic Loss: 0.1232
# Episode 90	Total Reward: -1.00	Actor Loss: -0.2370	Critic Loss: 0.0489
# Episode 100	Total Reward: -1.00	Actor Loss: -0.1524	Critic Loss: 0.0146
# Episode 110	Total Reward: -1.00	Actor Loss: -0.2160	Critic Loss: 0.0397
# Episode 120	Total Reward: -1.00	Actor Loss: -0.2892	Critic Loss: 0.0691
# Episode 130	Total Reward: -0.90	Actor Loss: 0.1165	Critic Loss: 0.0192
# Episode 140	Total Reward: -1.00	Actor Loss: -0.1889	Critic Loss: 0.0188
# Episode 150	Total Reward: -1.00	Actor Loss: -0.1106	Critic Loss: 0.0088
# Episode 160	Total Reward: -1.00	Actor Loss: 0.0210	Critic Loss: 0.0003
# Episode 170	Total Reward: -0.80	Actor Loss: -0.0240	Critic Loss: 0.0157
# Episode 180	Total Reward: -1.00	Actor Loss: -0.0720	Critic Loss: 0.0021
# Episode 190	Total Reward: 13.50	Actor Loss: 0.1039	Critic Loss: 59.3444
# Episode 200	Total Reward: -1.00	Actor Loss: -0.1323	Critic Loss: 0.0061
# Episode 210	Total Reward: 25.40	Actor Loss: -0.0139	Critic Loss: 87.4061
# Episode 220	Total Reward: -1.00	Actor Loss: -1.1087	Critic Loss: 0.1439
# Episode 230	Total Reward: 22.20	Actor Loss: -0.1001	Critic Loss: 59.9860
# Episode 240	Total Reward: 23.80	Actor Loss: -0.0268	Critic Loss: 19.5473
# Episode 250	Total Reward: 26.30	Actor Loss: -0.0393	Critic Loss: 26.5649
# Episode 260	Total Reward: 26.20	Actor Loss: -0.0502	Critic Loss: 28.6930
# Episode 270	Total Reward: 33.10	Actor Loss: -0.0084	Critic Loss: 48.1851
# Episode 280	Total Reward: 30.30	Actor Loss: -0.0961	Critic Loss: 24.0736
# Episode 290	Total Reward: 30.80	Actor Loss: -0.0544	Critic Loss: 22.9464
# Episode 300	Total Reward: 28.80	Actor Loss: 0.0069	Critic Loss: 49.0709
# Episode 310	Total Reward: 27.90	Actor Loss: -0.1866	Critic Loss: 96.3936
# Episode 320	Total Reward: 25.20	Actor Loss: 0.0021	Critic Loss: 16.9472
# Episode 330	Total Reward: 30.00	Actor Loss: 0.0022	Critic Loss: 27.2407
# Episode 340	Total Reward: 27.70	Actor Loss: -0.0085	Critic Loss: 14.7532
# Episode 350	Total Reward: 25.50	Actor Loss: 0.0050	Critic Loss: 10.5819
# Episode 360	Total Reward: 27.20	Actor Loss: -0.0059	Critic Loss: 13.4935
# Episode 370	Total Reward: 31.60	Actor Loss: 0.0054	Critic Loss: 30.7356
# Episode 380	Total Reward: 33.10	Actor Loss: -0.0232	Critic Loss: 37.4288
# Episode 390	Total Reward: 24.20	Actor Loss: -0.0951	Critic Loss: 120.0592
# Episode 400	Total Reward: 36.30	Actor Loss: -0.0513	Critic Loss: 76.1847
# Episode 410	Total Reward: 16.20	Actor Loss: -0.5129	Critic Loss: 1107.0305
# Episode 420	Total Reward: 23.60	Actor Loss: -0.1348	Critic Loss: 72.1886
# Episode 430	Total Reward: 285.10	Actor Loss: 0.3070	Critic Loss: 57659.9570
# Episode 440	Total Reward: 166.20	Actor Loss: -0.0267	Critic Loss: 3738.1218
# Episode 450	Total Reward: 18.30	Actor Loss: -0.9872	Critic Loss: 4959.1875
# Episode 460	Total Reward: 54.10	Actor Loss: -0.5513	Critic Loss: 690.9175
# Episode 470	Total Reward: 28.70	Actor Loss: -0.4146	Critic Loss: 1578.6925
# Episode 480	Total Reward: 465.20	Actor Loss: 0.4390	Critic Loss: 113505.3516
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 122
#     118 # --- Training ---
#     119 print(f"Starting training for {config['num_episodes']} episodes...")
#     121 total_rewards_history, actor_loss_history, critic_loss_history, \
# --> 122 actor_firing_rates, critic_firing_rates = train_agent(
#     123     env=env,
#     124     agent=agent,
#     125     num_episodes=config["num_episodes"],
#     126     gamma=config["gamma"],
#     127     print_interval=config["print_interval"],
#     128     l2_actor=config["l2_actor"],
#     129     l2_critic=config["l2_critic"],
#     130     record_history=config["record_history"]
#     131 )
#     133 print("\nTraining finished.")
#     135 # --- Plot Training Metrics ---
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/reinforce.py:86, in train_agent(env, agent, num_episodes, gamma, print_interval, record_history, l2_actor, l2_critic)
#      83     actor_hidden_states_ep.append(current_actor_hidden[0].numpy().flatten())
#      85 # Environment steps
# ---> 86 next_state, reward, terminated, truncated, _ = env.step(action)
#      87 done = terminated or truncated
#      89 # Store data for this step
#
# File /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/env_economic_choice_2.py:247, in EconomicChoiceEnv.step(self, action)
#     245 """Advances the environment by one time step."""
#     246 if not (0 <= action < self.action_space.n):
# --> 247     raise ValueError(f"Invalid action: {action}. Action must be in [0, {self.action_space.n-1}]")
#     249 terminated = False
#     250 truncated = False
#
# ValueError: Invalid action: 3. Action must be in [0, 2]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
