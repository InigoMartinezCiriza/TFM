# %% [markdown]
# ### RNN: economic choice

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_final import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 0
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Define Paths for Loading/Saving ---
load_weights_path = None
save_weights_path = "saved_models/stage1"

# Ensure save directory exists
save_dir = os.path.dirname(save_weights_path)
if save_dir and not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f"Created directory '{save_dir}'")


# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 500,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

# Load weights
if load_weights_path:
    print(f"Attempting to load weights from: {load_weights_path}")
    load_successful = agent.load_weights(load_weights_path)
    if not load_successful:
        print(f"WARNING: Failed to load weights. Starting training with initialized weights.")
else:
    print("No weights loaded (load_weights_path is None). Starting from scratch.")

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# Save weights
if save_weights_path:
    print(f"Saving agent weights to: {save_weights_path}")
    agent.save_weights(save_weights_path)
else:
    print("No save path specified (save_weights_path is None). Weights not saved.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# 2025-04-23 16:08:33.581008: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745417314.399924  370090 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745417314.611020  370090 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745417316.486235  370090 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745417316.486289  370090 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745417316.486291  370090 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745417316.486292  370090 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-23 16:08:36.681011: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 500
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('B', 'A'), 'offer_BA': (6, 1), 'nL': 6, 'nR': 1, 'rL': 600, 'rR': 220.00000000000003, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# 2025-04-23 16:09:19.548016: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# No weights loaded (load_weights_path is None). Starting from scratch.
# Agent Initialized.
# Starting training for 500 episodes...
# Episode 10	Total Reward: -1.00	Actor Loss: -1.0144	Critic Loss: 0.7834
# Episode 20	Total Reward: -1.00	Actor Loss: -0.5557	Critic Loss: 0.2793
# Episode 30	Total Reward: -1.00	Actor Loss: 0.0646	Critic Loss: 0.0039
# Episode 40	Total Reward: -1.00	Actor Loss: -0.1860	Critic Loss: 0.0307
# Episode 50	Total Reward: -1.00	Actor Loss: -0.1401	Critic Loss: 0.0174
# Episode 60	Total Reward: -0.90	Actor Loss: 0.5107	Critic Loss: 0.3489
# Episode 70	Total Reward: -0.70	Actor Loss: 0.8607	Critic Loss: 0.9802
# Episode 80	Total Reward: -1.00	Actor Loss: -0.4363	Critic Loss: 0.1232
# Episode 90	Total Reward: -1.00	Actor Loss: -0.2384	Critic Loss: 0.0495
# Episode 100	Total Reward: -1.00	Actor Loss: -0.1523	Critic Loss: 0.0145
# Episode 110	Total Reward: -1.00	Actor Loss: -0.2155	Critic Loss: 0.0396
# Episode 120	Total Reward: -1.00	Actor Loss: -0.2896	Critic Loss: 0.0693
# Episode 130	Total Reward: -0.90	Actor Loss: 0.1156	Critic Loss: 0.0190
# Episode 140	Total Reward: -1.00	Actor Loss: -0.1909	Critic Loss: 0.0192
# Episode 150	Total Reward: -1.00	Actor Loss: -0.1087	Critic Loss: 0.0085
# Episode 160	Total Reward: -1.00	Actor Loss: 0.0223	Critic Loss: 0.0004
# Episode 170	Total Reward: -0.80	Actor Loss: -0.0209	Critic Loss: 0.0156
# Episode 180	Total Reward: 11.20	Actor Loss: 0.0144	Critic Loss: 82.6240
# Episode 190	Total Reward: -1.00	Actor Loss: -0.0225	Critic Loss: 0.0004
# Episode 200	Total Reward: -0.90	Actor Loss: -0.0777	Critic Loss: 0.0022
# Episode 210	Total Reward: 28.10	Actor Loss: 0.0454	Critic Loss: 213.1765
# Episode 220	Total Reward: 26.40	Actor Loss: 0.1895	Critic Loss: 333.2222
# Episode 230	Total Reward: 25.40	Actor Loss: 0.0372	Critic Loss: 134.5468
# Episode 240	Total Reward: -0.80	Actor Loss: -1.7640	Critic Loss: 0.2593
# Episode 250	Total Reward: 30.20	Actor Loss: -0.0610	Critic Loss: 130.7876
# Episode 260	Total Reward: 7.80	Actor Loss: 0.0020	Critic Loss: 21.8682
# Episode 270	Total Reward: 25.90	Actor Loss: -0.0053	Critic Loss: 107.0288
# Episode 280	Total Reward: 23.00	Actor Loss: 0.2105	Critic Loss: 72.9608
# Episode 290	Total Reward: 11.90	Actor Loss: 0.0021	Critic Loss: 19.1795
# Episode 300	Total Reward: 9.00	Actor Loss: 0.0020	Critic Loss: 21.6516
# Episode 310	Total Reward: 12.20	Actor Loss: 0.0020	Critic Loss: 9.4953
# Episode 320	Total Reward: 27.70	Actor Loss: 0.0395	Critic Loss: 118.6593
# Episode 330	Total Reward: 10.70	Actor Loss: 0.0021	Critic Loss: 17.9797
# Episode 340	Total Reward: 6.50	Actor Loss: 0.0020	Critic Loss: 126.9057
# Episode 350	Total Reward: 8.90	Actor Loss: 0.0020	Critic Loss: 53.4497
# Episode 360	Total Reward: 5.10	Actor Loss: 0.0020	Critic Loss: 13.4684
# Episode 370	Total Reward: 26.50	Actor Loss: 0.0010	Critic Loss: 110.2260
# Episode 380	Total Reward: 32.10	Actor Loss: 0.1093	Critic Loss: 243.1975
# Episode 390	Total Reward: 28.70	Actor Loss: -0.1825	Critic Loss: 370.6495
# Episode 400	Total Reward: 24.00	Actor Loss: 0.0265	Critic Loss: 25.7108
# Episode 410	Total Reward: 25.50	Actor Loss: -0.0437	Critic Loss: 46.7207
# Episode 420	Total Reward: 24.70	Actor Loss: -0.0287	Critic Loss: 28.1034
# Episode 430	Total Reward: 23.50	Actor Loss: -0.0182	Critic Loss: 24.7919
# Episode 440	Total Reward: 33.30	Actor Loss: -0.0892	Critic Loss: 44.5027
# Episode 450	Total Reward: 30.20	Actor Loss: -0.0186	Critic Loss: 34.1553
# Episode 460	Total Reward: 28.70	Actor Loss: -0.0041	Critic Loss: 17.0309
# Episode 470	Total Reward: 29.80	Actor Loss: -0.0038	Critic Loss: 28.6943
# Episode 480	Total Reward: 25.30	Actor Loss: -0.0183	Critic Loss: 15.3309
# Episode 490	Total Reward: 38.90	Actor Loss: 0.0598	Critic Loss: 401.8553
# Episode 500	Total Reward: 24.00	Actor Loss: -0.0927	Critic Loss: 31.5072
#
# Training finished.
# Saving agent weights to: saved_models/stage1
# Agent weights saved: saved_models/stage1
# Plotting training metrics...
# Metrics plot displayed.
# Plotting neuron firing rates...
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:93: RuntimeWarning: Mean of empty slice
#   first_episode = np.nanmean(tensor[:, :, 0], axis=0)
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:94: RuntimeWarning: Mean of empty slice
#   last_episode = np.nanmean(tensor[:, :, -1], axis=0)
# Firing rate plot displayed.
# Closing the environment...
# Environment closed.

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_final import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 1
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Define Paths for Loading/Saving ---
load_weights_path = "saved_models/stage1"
save_weights_path = "saved_models/stage1_part2"

# Ensure save directory exists
save_dir = os.path.dirname(save_weights_path)
if save_dir and not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f"Created directory '{save_dir}'")


# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 500,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

# Load weights
if load_weights_path:
    print(f"Attempting to load weights from: {load_weights_path}")
    load_successful = agent.load_weights(load_weights_path)
    if not load_successful:
        print(f"WARNING: Failed to load weights. Starting training with initialized weights.")
else:
    print("No weights loaded (load_weights_path is None). Starting from scratch.")

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# Save weights
if save_weights_path:
    print(f"Saving agent weights to: {save_weights_path}")
    agent.save_weights(save_weights_path)
else:
    print("No save path specified (save_weights_path is None). Weights not saved.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# 2025-04-23 18:54:20.727475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745427262.335056  399417 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745427262.777966  399417 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745427266.662664  399417 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745427266.662728  399417 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745427266.662730  399417 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745427266.662732  399417 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-23 18:54:27.042797: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 500
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('A', 'B'), 'offer_BA': (1, 2), 'nL': 2, 'nR': 1, 'rL': 440.00000000000006, 'rR': 100, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# 2025-04-23 18:55:10.494826: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Attempting to load weights from: saved_models/stage1
# Warning: Could not load agent weights: You are loading weights into a model that has not yet been built. Try building the model first by calling it on some data or by using `build()`.
# WARNING: Failed to load weights. Starting training with initialized weights.
# Agent Initialized.
# Starting training for 500 episodes...
# Episode 10	Total Reward: -1.00	Actor Loss: -0.9397	Critic Loss: 0.7114
# Episode 20	Total Reward: -1.00	Actor Loss: -0.3522	Critic Loss: 0.1030
# Episode 30	Total Reward: -0.90	Actor Loss: 0.7881	Critic Loss: 0.6618
# Episode 390	Total Reward: 10.40	Actor Loss: 0.0024	Critic Loss: 226.6137
# Episode 400	Total Reward: 283.50	Actor Loss: 0.9811	Critic Loss: 61404.9570
# Episode 410	Total Reward: 1070.00	Actor Loss: 1.2106	Critic Loss: 1080694.6250
# Episode 420	Total Reward: 284.50	Actor Loss: 0.3275	Critic Loss: 58945.7812
# Episode 430	Total Reward: 64.10	Actor Loss: 0.0822	Critic Loss: 442.5959
# Episode 440	Total Reward: 262.50	Actor Loss: 0.4131	Critic Loss: 41991.3320
# Episode 450	Total Reward: 26.20	Actor Loss: -0.2941	Critic Loss: 424.8593
# Episode 460	Total Reward: 504.60	Actor Loss: 0.8438	Critic Loss: 196351.4062
# Episode 470	Total Reward: 468.60	Actor Loss: 0.9501	Critic Loss: 175421.9688
# Episode 480	Total Reward: 16.60	Actor Loss: -0.4406	Critic Loss: 508.7066
# Episode 490	Total Reward: 169.80	Actor Loss: 0.1918	Critic Loss: 16020.2471
# Episode 500	Total Reward: 266.60	Actor Loss: 0.2392	Critic Loss: 51833.7227
#
# Training finished.
# Saving agent weights to: saved_models/stage1_part2
# Agent weights saved: saved_models/stage1_part2
# Plotting training metrics...
# Metrics plot displayed.
# Plotting neuron firing rates...
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:93: RuntimeWarning: Mean of empty slice
#   first_episode = np.nanmean(tensor[:, :, 0], axis=0)
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules/helper_functions.py:94: RuntimeWarning: Mean of empty slice
#   last_episode = np.nanmean(tensor[:, :, -1], axis=0)
# Firing rate plot displayed.
# Closing the environment...
# Environment closed.

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_final import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 2
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Define Paths for Loading/Saving ---
load_weights_path = "saved_models/stage1_part2"
save_weights_path = "saved_models/stage1_part3"

# Ensure save directory exists
save_dir = os.path.dirname(save_weights_path)
if save_dir and not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f"Created directory '{save_dir}'")


# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 500,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

# Load weights
if load_weights_path:
    print(f"Attempting to load weights from: {load_weights_path}")
    load_successful = agent.load_weights(load_weights_path)
    if not load_successful:
        print(f"WARNING: Failed to load weights. Starting training with initialized weights.")
else:
    print("No weights loaded (load_weights_path is None). Starting from scratch.")

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# Save weights
if save_weights_path:
    print(f"Saving agent weights to: {save_weights_path}")
    agent.save_weights(save_weights_path)
else:
    print("No save path specified (save_weights_path is None). Weights not saved.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' already in sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 500
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('A', 'B'), 'offer_BA': (1, 2), 'nL': 2, 'nR': 1, 'rL': 440.00000000000006, 'rR': 100, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# Attempting to load weights from: saved_models/stage1_part2
# Warning: Could not load agent weights: You are loading weights into a model that has not yet been built. Try building the model first by calling it on some data or by using `build()`.
# WARNING: Failed to load weights. Starting training with initialized weights.
# Agent Initialized.
# Starting training for 500 episodes...
# Episode 10	Total Reward: -0.90	Actor Loss: -0.8238	Critic Loss: 0.5758
# Episode 20	Total Reward: -1.00	Actor Loss: -0.4300	Critic Loss: 0.1523
# Episode 30	Total Reward: -0.90	Actor Loss: 0.9731	Critic Loss: 1.0164
# Episode 40	Total Reward: -1.00	Actor Loss: -0.4055	Critic Loss: 0.1284
# Episode 50	Total Reward: -0.90	Actor Loss: -0.1473	Critic Loss: 0.0447
# Episode 60	Total Reward: -1.00	Actor Loss: -0.1517	Critic Loss: 0.0178
# Episode 70	Total Reward: -1.00	Actor Loss: -0.1978	Critic Loss: 0.0297
# Episode 80	Total Reward: -1.00	Actor Loss: -0.1726	Critic Loss: 0.0216
# Episode 90	Total Reward: -0.90	Actor Loss: 0.0862	Critic Loss: 0.0194
# Episode 100	Total Reward: -1.00	Actor Loss: -0.3068	Critic Loss: 0.0653
# Episode 110	Total Reward: -0.90	Actor Loss: 0.0654	Critic Loss: 0.0045
# Episode 120	Total Reward: -0.80	Actor Loss: 0.1721	Critic Loss: 0.0400
# Episode 470	Total Reward: 285.90	Actor Loss: -0.2309	Critic Loss: 21490.5098
# Episode 480	Total Reward: 1062.80	Actor Loss: 1.5948	Critic Loss: 634934.0000
# Episode 490	Total Reward: 28.00	Actor Loss: -2.1093	Critic Loss: 44843.9141
# Episode 500	Total Reward: 663.10	Actor Loss: 0.1634	Critic Loss: 249681.5469
#
# Training finished.
# Saving agent weights to: saved_models/stage1_part3
# Agent weights saved: saved_models/stage1_part3
# Plotting training metrics...
# Metrics plot displayed.
# Plotting neuron firing rates...
# Firing rate plot displayed.
# Closing the environment...
# Environment closed.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# --- Imports ---
import os
import sys
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_final import EconomicChoiceEnv
from actor_critic import ActorCriticAgent
from reinforce import train_agent
from helper_functions import plot_metrics, plot_firing_rates

# --- Set Random Seeds ---
seed_value = 3
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")

# --- Define Paths for Loading/Saving ---
load_weights_path = "saved_models/stage1_part3"
save_weights_path = "saved_models/stage1_part4"

# Ensure save directory exists
save_dir = os.path.dirname(save_weights_path)
if save_dir and not os.path.exists(save_dir):
    os.makedirs(save_dir)
    print(f"Created directory '{save_dir}'")


# --- Training Configuration ---
config = {
    # Environment specific params
    "env_dt_ms": 10,
    "A_to_B_ratio": 2.2,
    "reward_B": 100,
    "abort_penalty": -1.0,
    "input_noise_sigma": 0.01,
    "reward_fixation": 0.1,
    "reward_go_fixation": -0.1,
    "reward_choice_hold": 0.5,

    # Agent architecture
    "actor_hidden_size": 100,
    "critic_hidden_size": 100,
    "actor_layers": 1,
    "critic_layers": 1,
    "layer_type": "GRU_modified",
    "alpha": 0.1,
    "actor_prob_connection": 0.1,
    "critic_prob_connection": 1.0,

    # Training hyperparameters
    "actor_lr": 5e-3,
    "critic_lr": 5e-3,
    "num_episodes": 600,
    "gamma": 1.0,
    "l2_actor": 1e-4,
    "l2_critic": 1e-4,

    # Training process  
    "print_interval": 10,
    "record_history": 1
}

print("Configuration loaded:")
for key, value in config.items():
    print(f"  {key}: {value}")

# --- Environment Setup ---
print("Creating Padoa-Schioppa environment...")
env = EconomicChoiceEnv(
    dt=config["env_dt_ms"],
    A_to_B_ratio=config["A_to_B_ratio"],
    reward_B=config["reward_B"],
    abort_penalty=config["abort_penalty"],
    input_noise_sigma=config["input_noise_sigma"],
    reward_fixation=config["reward_fixation"],
    reward_go_fixation=config["reward_go_fixation"],
    reward_choice_hold=config["reward_choice_hold"]
)

# Get observation and action space sizes from the actual environment instance
obs_size = env.observation_space.shape[0]
act_size = env.action_space.n
print(f"Observation size: {obs_size}, Action size: {act_size}")

initial_obs, initial_info = env.reset(seed=seed_value)
print(f"Environment reset. Initial info: {initial_info}")

# --- Agent Setup ---
print("Initializing Actor-Critic Agent...")
agent = ActorCriticAgent(
    obs_size=obs_size,
    act_size=act_size,
    actor_hidden_size=config["actor_hidden_size"],
    critic_hidden_size=config["critic_hidden_size"],
    actor_layers=config["actor_layers"],
    critic_layers=config["critic_layers"],
    actor_lr=config["actor_lr"],
    critic_lr=config["critic_lr"],
    actor_prob_connection=config["actor_prob_connection"],
    critic_prob_connection=config["critic_prob_connection"],
    layer_type=config["layer_type"],
    alpha=config["alpha"]
)

# Load weights
if load_weights_path:
    print(f"Attempting to load weights from: {load_weights_path}")
    load_successful = agent.load_weights(load_weights_path)
    if not load_successful:
        print(f"WARNING: Failed to load weights. Starting training with initialized weights.")
else:
    print("No weights loaded (load_weights_path is None). Starting from scratch.")

print("Agent Initialized.")

# --- Training ---
print(f"Starting training for {config['num_episodes']} episodes...")

total_rewards_history, actor_loss_history, critic_loss_history, \
actor_firing_rates, critic_firing_rates = train_agent(
    env=env,
    agent=agent,
    num_episodes=config["num_episodes"],
    gamma=config["gamma"],
    print_interval=config["print_interval"],
    l2_actor=config["l2_actor"],
    l2_critic=config["l2_critic"],
    record_history=config["record_history"]
)

print("\nTraining finished.")

# Save weights
if save_weights_path:
    print(f"Saving agent weights to: {save_weights_path}")
    agent.save_weights(save_weights_path)
else:
    print("No save path specified (save_weights_path is None). Weights not saved.")

# --- Plot Training Metrics ---
print("Plotting training metrics...")
# Adjust window sizes if needed based on num_episodes
plot_metrics(
    total_rewards_history,
    actor_loss_history,
    critic_loss_history,
    window_1=max(20, config["num_episodes"] // 50),
    window_2=max(50, config["num_episodes"] // 10)
)

print("Metrics plot displayed.")

# --- Plot Firing Rates --- (Should still work if agent uses RNNs and logs them)
if actor_firing_rates is not None and critic_firing_rates is not None:
    print("Plotting neuron firing rates...")
    plot_firing_rates(actor_firing_rates, critic_firing_rates)
    print("Firing rate plot displayed.")
# Add checks for partial data as before...
elif actor_firing_rates is not None:
     print("Plotting only Actor firing rates (Critic might be Dense or logging failed)...")
     pass # Add specific plotting if desired
elif critic_firing_rates is not None:
     print("Plotting only Critic firing rates (Actor might be Dense or logging failed)...")
     pass # Add specific plotting if desired
else:
    print("Firing rate data not available (models might be Dense or logging was disabled/failed).")


# --- Close the Environment ---
print("Closing the environment...")
env.close()
print("Environment closed.")
# Out:
# 2025-04-24 07:27:38.749777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745472460.812779  483945 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745472461.368971  483945 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745472466.317787  483945 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745472466.317848  483945 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745472466.317850  483945 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745472466.317851  483945 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-24 07:27:46.792251: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código/Modules' to sys.path
# Setup Complete.
# Configuration loaded:
#   env_dt_ms: 10
#   A_to_B_ratio: 2.2
#   reward_B: 100
#   abort_penalty: -1.0
#   input_noise_sigma: 0.01
#   reward_fixation: 0.1
#   reward_go_fixation: -0.1
#   reward_choice_hold: 0.5
#   actor_hidden_size: 100
#   critic_hidden_size: 100
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: GRU_modified
#   alpha: 0.1
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.005
#   critic_lr: 0.005
#   num_episodes: 600
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 10
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Environment reset. Initial info: {'step': 0, 'epoch': 'fixation', 'juice_LR': ('A', 'B'), 'offer_BA': (2, 0), 'nL': 0, 'nR': 2, 'rL': 0.0, 'rR': 200, 'chosen_action': -1, 'choice_time_step': -1, 'is_correct_choice': None, 'A_to_B_ratio': 2.2, 'rewards_cfg': {'fix_step': 0.1, 'go_fix_step': -0.1, 'hold_step': 0.5, 'abort': -1.0}}
# Initializing Actor-Critic Agent...
# 2025-04-24 07:30:53.720283: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Attempting to load weights from: saved_models/stage1_part3
# Warning: Could not load agent weights: You are loading weights into a model that has not yet been built. Try building the model first by calling it on some data or by using `build()`.
# WARNING: Failed to load weights. Starting training with initialized weights.
# Agent Initialized.
# Starting training for 600 episodes...
# Episode 10	Total Reward: -1.00	Actor Loss: -0.8946	Critic Loss: 0.6560
# Episode 20	Total Reward: -1.00	Actor Loss: -0.3579	Critic Loss: 0.1035
# Episode 30	Total Reward: -1.00	Actor Loss: -0.0470	Critic Loss: 0.0020
# Episode 40	Total Reward: -1.00	Actor Loss: -0.1646	Critic Loss: 0.0224
# Episode 50	Total Reward: -1.00	Actor Loss: -0.2846	Critic Loss: 0.0661
# Episode 60	Total Reward: -1.00	Actor Loss: -0.2513	Critic Loss: 0.0506
# Episode 70	Total Reward: -1.00	Actor Loss: -0.0303	Critic Loss: 0.0009
# Episode 80	Total Reward: -1.00	Actor Loss: -0.0516	Critic Loss: 0.0022
# Episode 90	Total Reward: -1.00	Actor Loss: -0.2316	Critic Loss: 0.0419
# Episode 100	Total Reward: -1.00	Actor Loss: -0.1191	Critic Loss: 0.0110
# Episode 110	Total Reward: -1.00	Actor Loss: -0.0228	Critic Loss: 0.0006
# Episode 120	Total Reward: -0.80	Actor Loss: 0.0689	Critic Loss: 0.0079
# Episode 130	Total Reward: -0.80	Actor Loss: 0.1159	Critic Loss: 0.0167
# Episode 140	Total Reward: -0.90	Actor Loss: -0.0230	Critic Loss: 0.0008
# Episode 150	Total Reward: -0.90	Actor Loss: 0.0961	Critic Loss: 0.0066
# Episode 160	Total Reward: 5.50	Actor Loss: 0.0070	Critic Loss: 123.3722
# Episode 170	Total Reward: -0.90	Actor Loss: -0.0804	Critic Loss: 0.0042
# Episode 180	Total Reward: 22.70	Actor Loss: 0.1329	Critic Loss: 165.0586
# Episode 190	Total Reward: 11.90	Actor Loss: 0.0034	Critic Loss: 38.8749
# Episode 200	Total Reward: 22.70	Actor Loss: -0.0395	Critic Loss: 94.9701
# Episode 210	Total Reward: 27.50	Actor Loss: 0.0546	Critic Loss: 200.7816
# Episode 220	Total Reward: 6.90	Actor Loss: 0.0022	Critic Loss: 92.9173
# Episode 230	Total Reward: 30.90	Actor Loss: 0.1681	Critic Loss: 420.2624
# Episode 240	Total Reward: 30.30	Actor Loss: 0.0691	Critic Loss: 176.8204
