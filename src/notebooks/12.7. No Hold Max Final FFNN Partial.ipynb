# %% [markdown]
# ### FFNN Economic Choice No Hold
#
# Hopefully it works

# %%
# --- Imports ---
import os
import sys
import random
import pickle
import gymnasium as gym
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# --- GPU Configuration ---
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# --- Add Modules directory to Python path ---
module_path = os.path.abspath(os.path.join('.', 'Modules'))

if module_path not in sys.path:
    sys.path.append(module_path)
    print(f"Added '{module_path}' to sys.path")
else:
    print(f"'{module_path}' already in sys.path")

# --- Import custom modules ---
from env_economic_choice_no_hold_partial import EconomicChoiceEnv
from actor_critic_song import ActorCriticAgent
from reinforce_song import train_agent
from helper_functions import plot_metrics, plot_firing_rates, plot_psychometric_curve, load_model, save_model

# --- Set Random Seeds ---
seed_value = 1
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
random.seed(seed_value)

print("Setup Complete.")
# Out:
# 2025-06-05 20:54:58.964484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749149700.046211  243972 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749149700.396074  243972 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749149703.372158  243972 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749149703.372184  243972 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749149703.372186  243972 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749149703.372187  243972 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-05 20:55:03.697319: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Added '/mnt/c/Users/imcir/Desktop/CIENCIA DATOS/Segundo cuatrimestre/TFM/Código 2/Modules' to sys.path
# Setup Complete.

# %%
def main():
    # --- Training Configuration ---
    config = {
        # Environment params
        "dt": 10,
        "A_to_B_ratio": 2.2,
        "reward_B": 1,
        "abort_penalty": -0.1,
        "input_noise_sigma": 0.0,
        "reward_fixation": 0.01,
        "reward_go_fixation": -0.01,
        "duration_params": [10, 10, 20, 20],
        # Agent architecture
        "actor_hidden_size": 50,
        "critic_hidden_size": 50,
        "actor_layers": 1,
        "critic_layers": 1,
        "layer_type": 'Dense',
        "actor_prob_connection": 0.1,
        "critic_prob_connection": 1.0,
        # Training hyperparams
        "actor_lr": 4e-3,
        "critic_lr": 4e-3,
        "num_episodes": 10000,
        "gamma": 1.0,
        "l2_actor": 1e-4,
        "l2_critic": 1e-4,
        # Training process
        "print_interval": 100,
        "record_history": 1
    }

    print("Configuration loaded:")
    for key, value in config.items():
        print(f"  {key}: {value}")

    # --- Environment Setup ---
    print("Creating Padoa-Schioppa environment...")
    env = EconomicChoiceEnv(
        dt=config["dt"],
        A_to_B_ratio=config["A_to_B_ratio"],
        reward_B=config["reward_B"],
        abort_penalty=config["abort_penalty"],
        input_noise_sigma=config["input_noise_sigma"],
        reward_fixation=config["reward_fixation"],
        reward_go_fixation=config["reward_go_fixation"],
        duration_params=config["duration_params"]
    )
    obs_size = env.observation_space.shape[0]
    act_size = env.action_space.n
    print(f"Observation size: {obs_size}, Action size: {act_size}")

    # --- Agent Setup ---
    print("Initializing Actor-Critic Agent...")
    agent = ActorCriticAgent(
        obs_size=obs_size,
        act_size=act_size,
        actor_hidden_size=config["actor_hidden_size"],
        critic_hidden_size=config["critic_hidden_size"],
        actor_layers=config["actor_layers"],
        critic_layers=config["critic_layers"],
        actor_lr=config["actor_lr"],
        critic_lr=config["critic_lr"],
        actor_prob_connection=config["actor_prob_connection"],
        critic_prob_connection=config["critic_prob_connection"],
        layer_type=config["layer_type"]
    )
    print("Agent Initialized.")

    # --- Training ---
    print(f"Starting training for {config['num_episodes']} episodes...")
    total_rewards_history, actor_loss_history, critic_loss_history, \
    actor_firing_rates, critic_firing_rates, measurements_juices = train_agent(
        env=env,
        agent=agent,
        num_episodes=config["num_episodes"],
        gamma=config["gamma"],
        print_interval=config["print_interval"],
        l2_actor=config["l2_actor"],
        l2_critic=config["l2_critic"],
        record_history=config["record_history"]
    )
    print("\nTraining finished.")

    # --- Save checkpoint ---
    this_stage = 1
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    save_model(agent, this_stage, this_ckpt_dir)

    # --- Save outputs ---
    output_dir  = Path.cwd() / "outputs"
    output_dir.mkdir(parents=True, exist_ok=True)
    output_file = output_dir / "2_ffnn_nohold_max_partial.pkl"
    with open(output_file, "wb") as f:
        pickle.dump((
            total_rewards_history,
            actor_loss_history,
            critic_loss_history,
            actor_firing_rates,
            critic_firing_rates,
            measurements_juices
        ), f)

    # --- Plot Training Metrics & Psychometric Curve ---
    plot_metrics(
        total_rewards_history,
        actor_loss_history,
        critic_loss_history,
        window_1=max(20, config["num_episodes"] // 50),
        window_2=max(50, config["num_episodes"] // 10)
    )
    plot_psychometric_curve(
        measurements_juices,
        title="Psychometric Curve Stage 1"
    )

    # --- Close Environment ---
    print("Closing the environment...")
    env.close()
    print("Environment closed.")

if __name__ == '__main__':
    main()
# Out:
# Configuration loaded:
#   dt: 10
#   A_to_B_ratio: 2.2
#   reward_B: 1
#   abort_penalty: -0.1
#   input_noise_sigma: 0.0
#   reward_fixation: 0.01
#   reward_go_fixation: -0.01
#   duration_params: [10, 10, 20, 20]
#   actor_hidden_size: 50
#   critic_hidden_size: 50
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: Dense
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.004
#   critic_lr: 0.004
#   num_episodes: 10000
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 100
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Initializing Actor-Critic Agent...
# Agent Initialized.
# Starting training for 10000 episodes...
# 2025-06-05 19:25:50.849953: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Episode 100	Total Reward: -0.10	State [1. 0. 0. 0.]	Actor Loss: -0.0571	Critic Loss: 0.0031
# Episode 200	Total Reward: -0.09	State [0. 0. 0. 0.]	Actor Loss: -0.0378	Critic Loss: 0.0255
# Episode 300	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.3575	Critic Loss: 1.7229
# Episode 400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0133	Critic Loss: 0.0051
# Episode 500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.2004	Critic Loss: 0.5933
# Episode 600	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0206	Critic Loss: 0.0044
# Episode 700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0399	Critic Loss: 0.0356
# Episode 800	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.8118	Critic Loss: 5.0380
# Episode 900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: -0.0427	Critic Loss: 0.0633
# Episode 1000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: -0.0516	Critic Loss: 0.0908
# Episode 1100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: -0.0053	Critic Loss: 0.0130
# Episode 1200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: -0.0448	Critic Loss: 0.0333
# Episode 1300	Total Reward: 10.01	State [0. 0. 0. 0.]	Actor Loss: 5.3622	Critic Loss: 61.7139
# Episode 1400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: -0.0536	Critic Loss: 0.2106
# Episode 1500	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0973	Critic Loss: 1.0349
# Episode 1600	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.1593	Critic Loss: 5.2240
# Episode 1700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0093
# Episode 1800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0282	Critic Loss: 1.1002
# Episode 1900	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0312	Critic Loss: 1.6931
# Episode 2000	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0414	Critic Loss: 4.1175
# Episode 2100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0035	Critic Loss: 0.0054
# Episode 2200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0043	Critic Loss: 0.0703
# Episode 2300	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0226	Critic Loss: 4.9356
# Episode 2400	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: -0.0002	Critic Loss: 0.0356
# Episode 2500	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0040
# Episode 2600	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0078	Critic Loss: 4.3028
# Episode 2700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 0.0341
# Episode 2800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0019	Critic Loss: 1.5065
# Episode 2900	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0117	Critic Loss: 18.9372
# Episode 3000	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0006	Critic Loss: 0.1131
# Episode 3100	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0060	Critic Loss: 3.0815
# Episode 3200	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0322
# Episode 3300	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0006	Critic Loss: 1.1868
# Episode 3400	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0094	Critic Loss: 61.1822
# Episode 3500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0120	Critic Loss: 60.5968
# Episode 3600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0034	Critic Loss: 5.0617
# Episode 3700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0068
# Episode 3800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0005	Critic Loss: 1.2657
# Episode 3900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0147
# Episode 4000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0102
# Episode 4100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0041
# Episode 4200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0082
# Episode 4300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0150
# Episode 4400	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.6305
# Episode 4500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0055	Critic Loss: 59.9274
# Episode 4600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0029	Critic Loss: 4.1044
# Episode 4700	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 0.4138
# Episode 4800	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0033	Critic Loss: 13.3055
# Episode 4900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0655
# Episode 5000	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 2.6036
# Episode 5100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0015
# Episode 5200	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0053	Critic Loss: 55.0008
# Episode 5300	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0123
# Episode 5400	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0035	Critic Loss: 15.5257
# Episode 5500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0005
# Episode 5600	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0010
# Episode 5700	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0022	Critic Loss: 3.2715
# Episode 5800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 3.6579
# Episode 5900	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 0.6304
# Episode 6000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0457
# Episode 6100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.0083
# Episode 6200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.1677
# Episode 6300	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 4.0255
# Episode 6400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 1.6720
# Episode 6500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.2273
# Episode 6600	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0359
# Episode 6700	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0183
# Episode 6800	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0006	Critic Loss: 3.7746
# Episode 6900	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 5.1182
# Episode 7000	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 0.4667
# Episode 7100	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 0.8388
# Episode 7200	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.1462
# Episode 7300	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0036	Critic Loss: 61.5576
# Episode 7400	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0023	Critic Loss: 5.0987
# Episode 7500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0008
# Episode 7600	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0028	Critic Loss: 14.0704
# Episode 7700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0009
# Episode 7800	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.1181
# Episode 7900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0494
# Episode 8000	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 5.2812
# Episode 8100	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0005	Critic Loss: 5.8201
# Episode 8200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.0015
# Episode 8300	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 3.5691
# Episode 8400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 1.1710
# Episode 8500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 1.2855
# Episode 8600	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0369
# Episode 8700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0174
# Episode 8800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 1.3709
# Episode 8900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0095
# Episode 9000	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0019	Critic Loss: 4.7053
# Episode 9100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0085
# Episode 9200	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.1372
# Episode 9300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0479
# Episode 9400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0017
# Episode 9500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 1.2209
# Episode 9600	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 4.3729
# Episode 9700	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 4.6552
# Episode 9800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.7441
# Episode 9900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0305
# Episode 10000	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 4.8070
#
# Training finished.
# Checkpoint stage 1 saved at: checkpoints/2_ffnn_nohold_max_partial_1/ckpt-1
# Saving masks for stage 1...
# Masks saved for stage 1.
# Closing the environment...
# Environment closed.

# %%
def main():
    # --- Training Configuration ---
    config = {
        # Environment params
        "dt": 10,
        "A_to_B_ratio": 2.2,
        "reward_B": 1,
        "abort_penalty": -0.1,
        "input_noise_sigma": 0.01,
        "reward_fixation": 0.01,
        "reward_go_fixation": -0.01,
        "duration_params": [10, 10, 20, 20],
        # Agent architecture
        "actor_hidden_size": 50,
        "critic_hidden_size": 50,
        "actor_layers": 1,
        "critic_layers": 1,
        "layer_type": 'Dense',
        "actor_prob_connection": 0.1,
        "critic_prob_connection": 1.0,
        # Training hyperparams
        "actor_lr": 4e-3,
        "critic_lr": 4e-3,
        "num_episodes": 10000,
        "gamma": 1.0,
        "l2_actor": 1e-4,
        "l2_critic": 1e-4,
        # Training process
        "print_interval": 100,
        "record_history": 1
    }

    print("Configuration loaded:")
    for key, value in config.items():
        print(f"  {key}: {value}")

    # --- Environment Setup ---
    print("Creating Padoa-Schioppa environment...")
    env = EconomicChoiceEnv(
        dt=config["dt"],
        A_to_B_ratio=config["A_to_B_ratio"],
        reward_B=config["reward_B"],
        abort_penalty=config["abort_penalty"],
        input_noise_sigma=config["input_noise_sigma"],
        reward_fixation=config["reward_fixation"],
        reward_go_fixation=config["reward_go_fixation"],
        duration_params=config["duration_params"]
    )
    obs_size = env.observation_space.shape[0]
    act_size = env.action_space.n
    print(f"Observation size: {obs_size}, Action size: {act_size}")

    # --- Agent Setup ---
    print("Initializing Actor-Critic Agent...")
    agent = ActorCriticAgent(
        obs_size=obs_size,
        act_size=act_size,
        actor_hidden_size=config["actor_hidden_size"],
        critic_hidden_size=config["critic_hidden_size"],
        actor_layers=config["actor_layers"],
        critic_layers=config["critic_layers"],
        actor_lr=config["actor_lr"],
        critic_lr=config["critic_lr"],
        actor_prob_connection=config["actor_prob_connection"],
        critic_prob_connection=config["critic_prob_connection"],
        layer_type=config["layer_type"]
    )
    print("Agent Initialized.")

    # --- Load checkpoint ---
    this_stage = 2
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    load_model(agent, obs_size, act_size, this_stage, this_ckpt_dir)

    # --- Training ---
    print(f"Starting training for {config['num_episodes']} episodes...")
    total_rewards_history, actor_loss_history, critic_loss_history, actor_firing_rates, critic_firing_rates, measurements_juices = train_agent(
        env=env,
        agent=agent,
        num_episodes=config['num_episodes'],
        gamma=config['gamma'],
        print_interval=config['print_interval'],
        l2_actor=config['l2_actor'],
        l2_critic=config['l2_critic'],
        record_history=config['record_history']
    )
    print("Training stage 2 finished.")

    # --- Save checkpoint ---
    this_stage = 2
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    save_model(agent, this_stage, this_ckpt_dir)

    # --- Save outputs ---
    output_dir  = Path.cwd() / "outputs"
    output_dir.mkdir(parents=True, exist_ok=True)
    output_file = output_dir / '2_ffnn_nohold_max_partial_2.pkl'
    with open(output_file, "wb") as f:
        pickle.dump((
            total_rewards_history,
            actor_loss_history,
            critic_loss_history,
            actor_firing_rates,
            critic_firing_rates,
            measurements_juices
        ), f)

    # --- Plot Metrics & Psych Curve ---
    print("Plotting training metrics...")
    plot_metrics(
        total_rewards_history,
        actor_loss_history,
        critic_loss_history,
        window_1=max(20, config['num_episodes']//50),
        window_2=max(50, config['num_episodes']//10)
    )
    print("Plotting psychometric curve...")
    plot_psychometric_curve(measurements_juices, title="Psychometric Curve Stage 2")

    # --- Cleanup ---
    print("Closing environment...")
    env.close()
    print("Done.")


if __name__ == '__main__':
    main()
# Out:
# Configuration loaded:
#   dt: 10
#   A_to_B_ratio: 2.2
#   reward_B: 1
#   abort_penalty: -0.1
#   input_noise_sigma: 0.01
#   reward_fixation: 0.01
#   reward_go_fixation: -0.01
#   duration_params: [10, 10, 20, 20]
#   actor_hidden_size: 50
#   critic_hidden_size: 50
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: Dense
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.004
#   critic_lr: 0.004
#   num_episodes: 10000
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 100
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Initializing Actor-Critic Agent...
# Agent Initialized.
# Actor and Critic networks built.
# Performing dummy forward to build cells and weights for mask loading...
# Loading masks from stage 1...
# Masks loaded.
# Initializing optimizers with dummy step...
# Optimizers initialized.
# Restoring from checkpoint: checkpoints/2_ffnn_nohold_max_partial_1/ckpt-1
# Checkpoint restored successfully.
# Starting training for 10000 episodes...
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'actor_model_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'critic_model_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Episode 100	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.8920
# Episode 200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0221
# Episode 300	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0022	Critic Loss: 3.2165
# Episode 400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0047
# Episode 500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 1.0480
# Episode 600	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0031	Critic Loss: 61.0186
# Episode 700	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0210
# Episode 800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 1.5465
# Episode 900	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0003	Critic Loss: 5.0425
# Episode 1000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0118
# Episode 1100	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0055	Critic Loss: 13.8173
# Episode 1200	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0010	Critic Loss: 4.0549
# Episode 1300	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0667
# Episode 1400	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0032	Critic Loss: 13.0915
# Episode 1500	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0245
# Episode 1600	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0057	Critic Loss: 60.2905
# Episode 1700	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 0.6295
# Episode 1800	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0188
# Episode 1900	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0004	Critic Loss: 5.4041
# Episode 2000	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0026	Critic Loss: 1.0117
# Episode 2100	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0087	Critic Loss: 61.0512
# Episode 2200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0138
# Episode 2300	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.9545
# Episode 2400	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0042
# Episode 2500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0048
# Episode 2600	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.4695
# Episode 2700	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.1065
# Episode 2800	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0023
# Episode 2900	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0893
# Episode 3000	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0518
# Episode 3100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0112
# Episode 3200	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 1.3400
# Episode 3300	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0319
# Episode 3400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0020
# Episode 3500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 1.5041
# Episode 3600	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.6379
# Episode 3700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0047
# Episode 3800	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 4.6709
# Episode 3900	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.3980
# Episode 4000	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.6296
# Episode 4100	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.5017
# Episode 4200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0345
# Episode 4300	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0059
# Episode 4400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.2946
# Episode 4500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0030	Critic Loss: 58.6504
# Episode 4600	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0022	Critic Loss: 15.9632
# Episode 4700	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.3105
# Episode 4800	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0127
# Episode 4900	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0026	Critic Loss: 57.4482
# Episode 5000	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.1134
# Episode 5100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0310
# Episode 5200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0007
# Episode 5300	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0671
# Episode 5400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0075
# Episode 5500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 2.0491
# Episode 5600	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0118
# Episode 5700	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0054	Critic Loss: 58.7243
# Episode 5800	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0027
# Episode 5900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0029
# Episode 6000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0077
# Episode 6100	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0427
# Episode 6200	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 14.3475
# Episode 6300	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0032	Critic Loss: 59.1329
# Episode 6400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0060
# Episode 6500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0013
# Episode 6600	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0027	Critic Loss: 3.4300
# Episode 6700	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0030	Critic Loss: 57.9382
# Episode 6800	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 4.8061
# Episode 6900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0041
# Episode 7000	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0027	Critic Loss: 15.2210
# Episode 7100	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0001	Critic Loss: 5.1632
# Episode 7200	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 4.6198
# Episode 7300	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.5062
# Episode 7400	Total Reward: 4.01	State [0. 0. 0. 0.]	Actor Loss: 3.4062	Critic Loss: 3.4641
# Episode 7500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0065
# Episode 7600	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0315
# Episode 7700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0035
# Episode 7800	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0005	Critic Loss: 4.0041
# Episode 7900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0083
# Episode 8000	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 4.7080
# Episode 8100	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 4.9880
# Episode 8200	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0005	Critic Loss: 1.4243
# Episode 8300	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 4.4091
# Episode 8400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0064
# Episode 8500	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0560
# Episode 8600	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 3.5869
# Episode 8700	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 3.7144
# Episode 8800	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 4.6973
# Episode 8900	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 3.1328
# Episode 9000	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.0467
# Episode 9100	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 15.9130
# Episode 9200	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.8927
# Episode 9300	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0064
# Episode 9400	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 4.7880
# Episode 9500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0086
# Episode 9600	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 0.0410
# Episode 9700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0036
# Episode 9800	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0022
# Episode 9900	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0101	Critic Loss: 15.7112
# Episode 10000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0727
# Training stage 2 finished.
# Checkpoint stage 2 saved at: checkpoints/2_ffnn_nohold_max_partial_2/ckpt-1
# Saving masks for stage 2...
# Masks saved for stage 2.
# Plotting training metrics...
# Plotting psychometric curve...
# Closing environment...
# Done.

# %%
def main():
    # --- Training Configuration ---
    config = {
        # Environment params
        "dt": 10,
        "A_to_B_ratio": 2.2,
        "reward_B": 1,
        "abort_penalty": -0.1,
        "input_noise_sigma": 0.01,
        "reward_fixation": 0.01,
        "reward_go_fixation": -0.01,
        "duration_params": [10, 10, 20, 20],
        # Agent architecture
        "actor_hidden_size": 50,
        "critic_hidden_size": 50,
        "actor_layers": 1,
        "critic_layers": 1,
        "layer_type": 'Dense',
        "actor_prob_connection": 0.1,
        "critic_prob_connection": 1.0,
        # Training hyperparams
        "actor_lr": 4e-3,
        "critic_lr": 4e-3,
        "num_episodes": 10000,
        "gamma": 1.0,
        "l2_actor": 1e-4,
        "l2_critic": 1e-4,
        # Training process
        "print_interval": 100,
        "record_history": 1
    }

    print("Configuration loaded:")
    for key, value in config.items():
        print(f"  {key}: {value}")

    # --- Environment Setup ---
    print("Creating Padoa-Schioppa environment...")
    env = EconomicChoiceEnv(
        dt=config["dt"],
        A_to_B_ratio=config["A_to_B_ratio"],
        reward_B=config["reward_B"],
        abort_penalty=config["abort_penalty"],
        input_noise_sigma=config["input_noise_sigma"],
        reward_fixation=config["reward_fixation"],
        reward_go_fixation=config["reward_go_fixation"],
        duration_params=config["duration_params"]
    )
    obs_size = env.observation_space.shape[0]
    act_size = env.action_space.n
    print(f"Observation size: {obs_size}, Action size: {act_size}")

    # --- Agent Setup ---
    print("Initializing Actor-Critic Agent...")
    agent = ActorCriticAgent(
        obs_size=obs_size,
        act_size=act_size,
        actor_hidden_size=config["actor_hidden_size"],
        critic_hidden_size=config["critic_hidden_size"],
        actor_layers=config["actor_layers"],
        critic_layers=config["critic_layers"],
        actor_lr=config["actor_lr"],
        critic_lr=config["critic_lr"],
        actor_prob_connection=config["actor_prob_connection"],
        critic_prob_connection=config["critic_prob_connection"],
        layer_type=config["layer_type"]
    )
    print("Agent Initialized.")

    # --- Load checkpoint ---
    this_stage = 3
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    load_model(agent, obs_size, act_size, this_stage, this_ckpt_dir)

    # --- Training ---
    print(f"Starting training for {config['num_episodes']} episodes...")
    total_rewards_history, actor_loss_history, critic_loss_history, actor_firing_rates, critic_firing_rates, measurements_juices = train_agent(
        env=env,
        agent=agent,
        num_episodes=config['num_episodes'],
        gamma=config['gamma'],
        print_interval=config['print_interval'],
        l2_actor=config['l2_actor'],
        l2_critic=config['l2_critic'],
        record_history=config['record_history']
    )
    print("Training stage 3 finished.")

    # --- Save checkpoint ---
    this_stage = 3
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    save_model(agent, this_stage, this_ckpt_dir)

    # --- Save outputs ---
    output_dir  = Path.cwd() / "outputs"
    output_dir.mkdir(parents=True, exist_ok=True)
    output_file = output_dir / '2_ffnn_nohold_max_partial_3.pkl'
    with open(output_file, "wb") as f:
        pickle.dump((
            total_rewards_history,
            actor_loss_history,
            critic_loss_history,
            actor_firing_rates,
            critic_firing_rates,
            measurements_juices
        ), f)

    # --- Plot Metrics & Psych Curve ---
    print("Plotting training metrics...")
    plot_metrics(
        total_rewards_history,
        actor_loss_history,
        critic_loss_history,
        window_1=max(20, config['num_episodes']//50),
        window_2=max(50, config['num_episodes']//10)
    )
    print("Plotting psychometric curve...")
    plot_psychometric_curve(measurements_juices, title="Psychometric Curve Stage 3")

    # --- Cleanup ---
    print("Closing environment...")
    env.close()
    print("Done.")


if __name__ == '__main__':
    main()
# Out:
# Configuration loaded:
#   dt: 10
#   A_to_B_ratio: 2.2
#   reward_B: 1
#   abort_penalty: -0.1
#   input_noise_sigma: 0.01
#   reward_fixation: 0.01
#   reward_go_fixation: -0.01
#   duration_params: [10, 10, 20, 20]
#   actor_hidden_size: 50
#   critic_hidden_size: 50
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: Dense
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.004
#   critic_lr: 0.004
#   num_episodes: 10000
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 100
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Initializing Actor-Critic Agent...
# Agent Initialized.
# Actor and Critic networks built.
# Performing dummy forward to build cells and weights for mask loading...
# Loading masks from stage 2...
# Masks loaded.
# Initializing optimizers with dummy step...
# 2025-06-05 20:11:04.983247: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'actor_model', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'critic_model', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Optimizers initialized.
# Restoring from checkpoint: checkpoints/2_ffnn_nohold_max_partial_2/ckpt-1
# Checkpoint restored successfully.
# Starting training for 10000 episodes...
# Episode 100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0127
# Episode 200	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 1.0529
# Episode 300	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0101	Critic Loss: 1.1510
# Episode 400	Total Reward: -0.09	State [ 1.         -1.          0.14298408  0.08764412]	Actor Loss: -2.7374	Critic Loss: 5.1578
# Episode 500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0031	Critic Loss: 61.3987
# Episode 600	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0507	Critic Loss: 4.0607
# Episode 700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0146
# Episode 800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.1239	Critic Loss: 0.9525
# Episode 900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0045	Critic Loss: 0.0261
# Episode 1000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0044
# Episode 1100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0037
# Episode 1200	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0050	Critic Loss: 60.3291
# Episode 1300	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0035	Critic Loss: 59.8249
# Episode 1400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.1032
# Episode 1500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0611	Critic Loss: 0.9599
# Episode 1600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 4.7949
# Episode 1700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0082
# Episode 1800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0004	Critic Loss: 0.8797
# Episode 1900	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.0179
# Episode 2000	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 4.4961
# Episode 2100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0285
# Episode 2200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0055
# Episode 2300	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0043	Critic Loss: 4.0456
# Episode 2400	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0019	Critic Loss: 0.1280
# Episode 2500	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0126
# Episode 2600	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 5.1031
# Episode 2700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0022
# Episode 2800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.8131
# Episode 2900	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 16.0424
# Episode 3000	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0047	Critic Loss: 0.2508
# Episode 3100	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.1976
# Episode 3200	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0273
# Episode 3300	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 1.0914
# Episode 3400	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 60.1656
# Episode 3500	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0026	Critic Loss: 62.1017
# Episode 3600	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 4.7126
# Episode 3700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0020
# Episode 3800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0026	Critic Loss: 0.9843
# Episode 3900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0047
# Episode 4000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0233
# Episode 4100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0050
# Episode 4200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0078
# Episode 4300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0022
# Episode 4400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0069	Critic Loss: 1.0534
# Episode 4500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0031	Critic Loss: 60.3218
# Episode 4600	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 4.3727
# Episode 4700	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.5848
# Episode 4800	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0022	Critic Loss: 14.4918
# Episode 4900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 0.0530
# Episode 5000	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 2.9476
# Episode 5100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0022
# Episode 5200	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0026	Critic Loss: 59.2013
# Episode 5300	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 0.0466
# Episode 5400	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 15.6093
# Episode 5500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0025
# Episode 5600	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0046
# Episode 5700	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.1585
# Episode 5800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.5089
# Episode 5900	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.6093
# Episode 6000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0138
# Episode 6100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0019
# Episode 6200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0279
# Episode 6300	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0005	Critic Loss: 3.4314
# Episode 6400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0005	Critic Loss: 0.9428
# Episode 6500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0231
# Episode 6600	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0033
# Episode 6700	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0332
# Episode 6800	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 4.5280
# Episode 6900	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 4.2817
# Episode 7000	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 1.1105
# Episode 7100	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.5857
# Episode 7200	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 0.6574
# Episode 7300	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 59.9741
# Episode 7400	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 4.3553
# Episode 7500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0041
# Episode 7600	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 14.0839
# Episode 7700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0103
# Episode 7800	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0025
# Episode 7900	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0316
# Episode 8000	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 4.8540
# Episode 8100	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 5.6547
# Episode 8200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0193
# Episode 8300	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0027	Critic Loss: 3.1092
# Episode 8400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 0.9294
# Episode 8500	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0078	Critic Loss: 1.1409
# Episode 8600	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0101	Critic Loss: 0.1694
# Episode 8700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0167
# Episode 8800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0430	Critic Loss: 1.0540
# Episode 8900	Total Reward: -0.08	State [ 1.         -1.          0.          0.09643883]	Actor Loss: -0.4934	Critic Loss: 2.7770
# Episode 9000	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 4.1629
# Episode 9100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0018
# Episode 9200	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0029	Critic Loss: 0.6475
# Episode 9300	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0331
# Episode 9400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0018
# Episode 9500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0002	Critic Loss: 1.2898
# Episode 9600	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.1501	Critic Loss: 3.3778
# Episode 9700	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 5.2216
# Episode 9800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 3.5283
# Episode 9900	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.2055
# Episode 10000	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 4.8049
# Training stage 3 finished.
# Checkpoint stage 3 saved at: checkpoints/2_ffnn_nohold_max_partial_3/ckpt-1
# Saving masks for stage 3...
# Masks saved for stage 3.
# Plotting training metrics...
# Plotting psychometric curve...
# Closing environment...
# Done.

# %%
def main():
    # --- Training Configuration ---
    config = {
        # Environment params
        "dt": 10,
        "A_to_B_ratio": 2.2,
        "reward_B": 1,
        "abort_penalty": -0.1,
        "input_noise_sigma": 0.01,
        "reward_fixation": 0.01,
        "reward_go_fixation": -0.01,
        "duration_params": [10, 10, 20, 20],
        # Agent architecture
        "actor_hidden_size": 50,
        "critic_hidden_size": 50,
        "actor_layers": 1,
        "critic_layers": 1,
        "layer_type": 'Dense',
        "actor_prob_connection": 0.1,
        "critic_prob_connection": 1.0,
        # Training hyperparams
        "actor_lr": 4e-3,
        "critic_lr": 4e-3,
        "num_episodes": 10000,
        "gamma": 1.0,
        "l2_actor": 1e-4,
        "l2_critic": 1e-4,
        # Training process
        "print_interval": 100,
        "record_history": 1
    }

    print("Configuration loaded:")
    for key, value in config.items():
        print(f"  {key}: {value}")

    # --- Environment Setup ---
    print("Creating Padoa-Schioppa environment...")
    env = EconomicChoiceEnv(
        dt=config["dt"],
        A_to_B_ratio=config["A_to_B_ratio"],
        reward_B=config["reward_B"],
        abort_penalty=config["abort_penalty"],
        input_noise_sigma=config["input_noise_sigma"],
        reward_fixation=config["reward_fixation"],
        reward_go_fixation=config["reward_go_fixation"],
        duration_params=config["duration_params"]
    )
    obs_size = env.observation_space.shape[0]
    act_size = env.action_space.n
    print(f"Observation size: {obs_size}, Action size: {act_size}")

    # --- Agent Setup ---
    print("Initializing Actor-Critic Agent...")
    agent = ActorCriticAgent(
        obs_size=obs_size,
        act_size=act_size,
        actor_hidden_size=config["actor_hidden_size"],
        critic_hidden_size=config["critic_hidden_size"],
        actor_layers=config["actor_layers"],
        critic_layers=config["critic_layers"],
        actor_lr=config["actor_lr"],
        critic_lr=config["critic_lr"],
        actor_prob_connection=config["actor_prob_connection"],
        critic_prob_connection=config["critic_prob_connection"],
        layer_type=config["layer_type"]
    )
    print("Agent Initialized.")

    # --- Load checkpoint ---
    this_stage = 4
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    load_model(agent, obs_size, act_size, this_stage, this_ckpt_dir)

    # --- Training ---
    print(f"Starting training for {config['num_episodes']} episodes...")
    total_rewards_history, actor_loss_history, critic_loss_history, actor_firing_rates, critic_firing_rates, measurements_juices = train_agent(
        env=env,
        agent=agent,
        num_episodes=config['num_episodes'],
        gamma=config['gamma'],
        print_interval=config['print_interval'],
        l2_actor=config['l2_actor'],
        l2_critic=config['l2_critic'],
        record_history=config['record_history']
    )
    print("Training stage 4 finished.")

    # --- Save checkpoint ---
    this_stage = 4
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    save_model(agent, this_stage, this_ckpt_dir)

    # --- Save outputs ---
    output_dir  = Path.cwd() / "outputs"
    output_dir.mkdir(parents=True, exist_ok=True)
    output_file = output_dir / '2_ffnn_nohold_max_partial_4.pkl'
    with open(output_file, "wb") as f:
        pickle.dump((
            total_rewards_history,
            actor_loss_history,
            critic_loss_history,
            actor_firing_rates,
            critic_firing_rates,
            measurements_juices
        ), f)

    # --- Plot Metrics & Psych Curve ---
    print("Plotting training metrics...")
    plot_metrics(
        total_rewards_history,
        actor_loss_history,
        critic_loss_history,
        window_1=max(20, config['num_episodes']//50),
        window_2=max(50, config['num_episodes']//10)
    )
    print("Plotting psychometric curve...")
    plot_psychometric_curve(measurements_juices, title="Psychometric Curve Stage 3")

    # --- Cleanup ---
    print("Closing environment...")
    env.close()
    print("Done.")


if __name__ == '__main__':
    main()
# Out:
# Configuration loaded:
#   dt: 10
#   A_to_B_ratio: 2.2
#   reward_B: 1
#   abort_penalty: -0.1
#   input_noise_sigma: 0.01
#   reward_fixation: 0.01
#   reward_go_fixation: -0.01
#   duration_params: [10, 10, 20, 20]
#   actor_hidden_size: 50
#   critic_hidden_size: 50
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: Dense
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.004
#   critic_lr: 0.004
#   num_episodes: 10000
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 100
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Initializing Actor-Critic Agent...
# 2025-06-05 20:55:43.747261: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'actor_model', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'critic_model', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Agent Initialized.
# Actor and Critic networks built.
# Performing dummy forward to build cells and weights for mask loading...
# Loading masks from stage 3...
# Masks loaded.
# Initializing optimizers with dummy step...
# Optimizers initialized.
# Restoring from checkpoint: checkpoints/2_ffnn_nohold_max_partial_3/ckpt-1
# Checkpoint restored successfully.
# Starting training for 10000 episodes...
# Episode 100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.0090
# Episode 200	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.7295
# Episode 300	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 1.0348
# Episode 400	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.2047
# Episode 500	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0020	Critic Loss: 59.8626
# Episode 600	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0017	Critic Loss: 3.0584
# Episode 700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0095
# Episode 800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.7476
# Episode 900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0156
# Episode 1000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0085
# Episode 1100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0015
# Episode 1200	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0031	Critic Loss: 60.1401
# Episode 1300	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0030	Critic Loss: 59.3856
# Episode 1400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0700
# Episode 1500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0002	Critic Loss: 0.7407
# Episode 1600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0023	Critic Loss: 4.7395
# Episode 1700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0011
# Episode 1800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.3337
# Episode 1900	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 1.0627
# Episode 2000	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0006	Critic Loss: 4.4559
# Episode 2100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0025
# Episode 2200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0017
# Episode 2300	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: -0.0006	Critic Loss: 3.7212
# Episode 2400	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0294
# Episode 2500	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0252
# Episode 2600	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 5.0653
# Episode 2700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0006
# Episode 2800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0003	Critic Loss: 0.7956
# Episode 2900	Total Reward: 6.02	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 15.3572
# Episode 3000	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0809
# Episode 3100	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0065	Critic Loss: 3.0866
# Episode 3200	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0009	Critic Loss: 0.0174
# Episode 3300	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0040	Critic Loss: 0.9772
# Episode 3400	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0028	Critic Loss: 60.2845
# Episode 3500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0023	Critic Loss: 61.8668
# Episode 3600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 4.6328
# Episode 3700	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0019
# Episode 3800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0047	Critic Loss: 1.0521
# Episode 3900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0014
# Episode 4000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0219
# Episode 4100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0048
# Episode 4200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0107
# Episode 4300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0039
# Episode 4400	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.8805
# Episode 4500	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0027	Critic Loss: 60.6211
# Episode 4600	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 4.7255
# Episode 4700	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.7210
# Episode 4800	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 14.2359
# Episode 4900	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0350
# Episode 5000	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 2.9894
# Episode 5100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0022
# Episode 5200	Total Reward: 10.02	State [0. 0. 0. 0.]	Actor Loss: 0.0025	Critic Loss: 59.3803
# Episode 5300	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0064
# Episode 5400	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 15.4635
# Episode 5500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0026
# Episode 5600	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0103
# Episode 5700	Total Reward: 4.02	State [0. 0. 0. 0.]	Actor Loss: 0.0016	Critic Loss: 3.2886
# Episode 5800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 3.4863
# Episode 5900	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.7733
# Episode 6000	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0092
# Episode 6100	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0024
# Episode 6200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0220
# Episode 6300	Total Reward: -0.08	State [ 1.         -1.          0.17911536  0.        ]	Actor Loss: -1.8600	Critic Loss: 2.5305
# Episode 6400	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 0.9740
# Episode 6500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0096
# Episode 6600	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0023
# Episode 6700	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0526
# Episode 6800	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 4.4447
# Episode 6900	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0018	Critic Loss: 4.3930
# Episode 7000	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.6307
# Episode 7100	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.7083
# Episode 7200	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.8268
# Episode 7300	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0023	Critic Loss: 59.1250
# Episode 7400	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 4.5153
# Episode 7500	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0030
# Episode 7600	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 13.9037
# Episode 7700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0151
# Episode 7800	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0064
# Episode 7900	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0401
# Episode 8000	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 4.7899
# Episode 8100	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 5.5790
# Episode 8200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0133
# Episode 8300	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0051	Critic Loss: 2.5910
# Episode 8400	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.5140
# Episode 8500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0007	Critic Loss: 1.2733
# Episode 8600	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0069	Critic Loss: 0.1194
# Episode 8700	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0083
# Episode 8800	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 1.1035
# Episode 8900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0014	Critic Loss: 0.2863
# Episode 9000	Total Reward: 4.43	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 4.4527
# Episode 9100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0007
# Episode 9200	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0004	Critic Loss: 1.2787
# Episode 9300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0010	Critic Loss: 0.0365
# Episode 9400	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0018
# Episode 9500	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: -0.0040	Critic Loss: 1.0906
# Episode 9600	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.1097	Critic Loss: 3.0829
# Episode 9700	Total Reward: 4.42	State [0. 0. 0. 0.]	Actor Loss: 0.0035	Critic Loss: 5.1298
# Episode 9800	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 3.6360
# Episode 9900	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0093	Critic Loss: 0.0565
# Episode 10000	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 4.7919
# Training stage 4 finished.
# Checkpoint stage 4 saved at: checkpoints/2_ffnn_nohold_max_partial_4/ckpt-1
# Saving masks for stage 4...
# Masks saved for stage 4.
# Plotting training metrics...
# Plotting psychometric curve...
# Closing environment...
# Done.

# %%
def main():
    # --- Training Configuration ---
    config = {
        # Environment params
        "dt": 10,
        "A_to_B_ratio": 2.2,
        "reward_B": 1,
        "abort_penalty": -0.1,
        "input_noise_sigma": 0.01,
        "reward_fixation": 0.01,
        "reward_go_fixation": -0.01,
        "duration_params": [10, 10, 20, 20],
        # Agent architecture
        "actor_hidden_size": 50,
        "critic_hidden_size": 50,
        "actor_layers": 1,
        "critic_layers": 1,
        "layer_type": 'Dense',
        "actor_prob_connection": 0.1,
        "critic_prob_connection": 1.0,
        # Training hyperparams
        "actor_lr": 4e-3,
        "critic_lr": 4e-3,
        "num_episodes": 3550,
        "gamma": 1.0,
        "l2_actor": 1e-4,
        "l2_critic": 1e-4,
        # Training process
        "print_interval": 100,
        "record_history": 1
    }

    print("Configuration loaded:")
    for key, value in config.items():
        print(f"  {key}: {value}")

    # --- Environment Setup ---
    print("Creating Padoa-Schioppa environment...")
    env = EconomicChoiceEnv(
        dt=config["dt"],
        A_to_B_ratio=config["A_to_B_ratio"],
        reward_B=config["reward_B"],
        abort_penalty=config["abort_penalty"],
        input_noise_sigma=config["input_noise_sigma"],
        reward_fixation=config["reward_fixation"],
        reward_go_fixation=config["reward_go_fixation"],
        duration_params=config["duration_params"]
    )
    obs_size = env.observation_space.shape[0]
    act_size = env.action_space.n
    print(f"Observation size: {obs_size}, Action size: {act_size}")

    # --- Agent Setup ---
    print("Initializing Actor-Critic Agent...")
    agent = ActorCriticAgent(
        obs_size=obs_size,
        act_size=act_size,
        actor_hidden_size=config["actor_hidden_size"],
        critic_hidden_size=config["critic_hidden_size"],
        actor_layers=config["actor_layers"],
        critic_layers=config["critic_layers"],
        actor_lr=config["actor_lr"],
        critic_lr=config["critic_lr"],
        actor_prob_connection=config["actor_prob_connection"],
        critic_prob_connection=config["critic_prob_connection"],
        layer_type=config["layer_type"]
    )
    print("Agent Initialized.")

    # --- Load checkpoint ---
    this_stage = 5
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    load_model(agent, obs_size, act_size, this_stage, this_ckpt_dir)

    # --- Training ---
    print(f"Starting training for {config['num_episodes']} episodes...")
    total_rewards_history, actor_loss_history, critic_loss_history, actor_firing_rates, critic_firing_rates, measurements_juices = train_agent(
        env=env,
        agent=agent,
        num_episodes=config['num_episodes'],
        gamma=config['gamma'],
        print_interval=config['print_interval'],
        l2_actor=config['l2_actor'],
        l2_critic=config['l2_critic'],
        record_history=config['record_history']
    )
    print("Training stage 5 finished.")

    # --- Save checkpoint ---
    this_stage = 5
    this_ckpt_dir = 'checkpoints/2_ffnn_nohold_max_partial'
    save_model(agent, this_stage, this_ckpt_dir)

    # --- Save outputs ---
    output_dir  = Path.cwd() / "outputs"
    output_dir.mkdir(parents=True, exist_ok=True)
    output_file = output_dir / '2_ffnn_nohold_max_partial_5.pkl'
    with open(output_file, "wb") as f:
        pickle.dump((
            total_rewards_history,
            actor_loss_history,
            critic_loss_history,
            actor_firing_rates,
            critic_firing_rates,
            measurements_juices
        ), f)

    # --- Plot Metrics & Psych Curve ---
    print("Plotting training metrics...")
    plot_metrics(
        total_rewards_history,
        actor_loss_history,
        critic_loss_history,
        window_1=max(20, config['num_episodes']//50),
        window_2=max(50, config['num_episodes']//10)
    )
    print("Plotting psychometric curve...")
    plot_psychometric_curve(measurements_juices, title="Psychometric Curve Stage 3")

    # --- Cleanup ---
    print("Closing environment...")
    env.close()
    print("Done.")


if __name__ == '__main__':
    main()
# Out:
# Configuration loaded:
#   dt: 10
#   A_to_B_ratio: 2.2
#   reward_B: 1
#   abort_penalty: -0.1
#   input_noise_sigma: 0.01
#   reward_fixation: 0.01
#   reward_go_fixation: -0.01
#   duration_params: [10, 10, 20, 20]
#   actor_hidden_size: 50
#   critic_hidden_size: 50
#   actor_layers: 1
#   critic_layers: 1
#   layer_type: Dense
#   actor_prob_connection: 0.1
#   critic_prob_connection: 1.0
#   actor_lr: 0.004
#   critic_lr: 0.004
#   num_episodes: 3550
#   gamma: 1.0
#   l2_actor: 0.0001
#   l2_critic: 0.0001
#   print_interval: 100
#   record_history: 1
# Creating Padoa-Schioppa environment...
# Observation size: 4, Action size: 3
# Initializing Actor-Critic Agent...
# Agent Initialized.
# Actor and Critic networks built.
# Performing dummy forward to build cells and weights for mask loading...
# Loading masks from stage 4...
# Masks loaded.
# Initializing optimizers with dummy step...
# Optimizers initialized.
# Restoring from checkpoint: checkpoints/2_ffnn_nohold_max_partial_4/ckpt-1
# Checkpoint restored successfully.
# Starting training for 3550 episodes...
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'actor_model_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /mnt/c/Users/imcir/Desktop/CIENCIA DATOS/cienciadatosenv/lib/python3.12/site-packages/keras/src/layers/layer.py:396: UserWarning: `build()` was called on layer 'critic_model_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Episode 100	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0003	Critic Loss: 0.6747
# Episode 200	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0008
# Episode 300	Total Reward: 4.03	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 3.5808
# Episode 400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0048
# Episode 500	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0006	Critic Loss: 1.0107
# Episode 600	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0023	Critic Loss: 60.6245
# Episode 700	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0287	Critic Loss: 0.2098
# Episode 800	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0016	Critic Loss: 1.0076
# Episode 900	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: -0.0078	Critic Loss: 3.0146
# Episode 1000	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0020
# Episode 1100	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 14.7128
# Episode 1200	Total Reward: 0.02	State [0. 0. 0. 0.]	Actor Loss: 0.0007	Critic Loss: 4.9795
# Episode 1300	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0013	Critic Loss: 0.0438
# Episode 1400	Total Reward: 6.03	State [0. 0. 0. 0.]	Actor Loss: 0.0021	Critic Loss: 13.6531
# Episode 1500	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0323
# Episode 1600	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0033	Critic Loss: 60.6216
# Episode 1700	Total Reward: 3.02	State [0. 0. 0. 0.]	Actor Loss: 0.0015	Critic Loss: 0.9082
# Episode 1800	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0064
# Episode 1900	Total Reward: 0.03	State [0. 0. 0. 0.]	Actor Loss: 0.0008	Critic Loss: 4.8369
# Episode 2000	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.6080
# Episode 2100	Total Reward: 10.03	State [0. 0. 0. 0.]	Actor Loss: 0.0026	Critic Loss: 60.4494
# Episode 2200	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0091
# Episode 2300	Total Reward: 3.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 1.0653
# Episode 2400	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 0.0596
# Episode 2500	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0011	Critic Loss: 0.0036
# Episode 2600	Total Reward: 1.03	State [0. 0. 0. 0.]	Actor Loss: 0.0439	Critic Loss: 0.6821
# Episode 2700	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0189	Critic Loss: 0.8341
# Episode 2800	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0037
# Episode 2900	Total Reward: 2.03	State [0. 0. 0. 0.]	Actor Loss: 0.0017	Critic Loss: 0.1963
# Episode 3000	Total Reward: 2.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0258
# Episode 3100	Total Reward: 2.22	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0119
# Episode 3200	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: -0.0002	Critic Loss: 0.8911
# Episode 3300	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0041
# Episode 3400	Total Reward: 2.23	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.0042
# Episode 3500	Total Reward: 1.02	State [0. 0. 0. 0.]	Actor Loss: 0.0012	Critic Loss: 0.9280
# Training stage 5 finished.
# Checkpoint stage 5 saved at: checkpoints/2_ffnn_nohold_max_partial_5/ckpt-1
# Saving masks for stage 5...
# Masks saved for stage 5.
# Plotting training metrics...
# Plotting psychometric curve...
# Closing environment...
# Done.
